# %%
import pandas as pd

# %%
obgyn_by_county = "obgyn_by_county.csv"
underlying_cause = "underlying_cause.csv"
population_data = "Population_DataHR.csv"
household_income = "household-income-levels.csv"
median_income = "median-household-income.csv"

# %%
obgyn_by_county_df = pd.read_csv(obgyn_by_county, encoding="ISO-8859-1")
underlying_cause_df = pd.read_csv(underlying_cause, encoding="ISO-8859-1")
population_data_df = pd.read_csv(population_data, encoding="ISO-8859-1")
household_income_df = pd.read_csv(household_income, encoding="ISO-8859-1")
median_income_df = pd.read_csv(median_income, encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-8aa0ceb4efbc> in <module>
#       2 underlying_cause_df = pd.read_csv(underlying_cause, encoding="ISO-8859-1")
#       3 population_data_df = pd.read_csv(population_data, encoding="ISO-8859-1")
# ----> 4 household_income_df = pd.read_csv(household_income, encoding="ISO-8859-1")
#       5 median_income_df = pd.read_csv(median_income, encoding="ISO-8859-1")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'household-income-levels.csv' does not exist: b'household-income-levels.csv'

# %%
obgyn_by_county_df.head()
# Out:
#    County Name  Providers Count
# 0        ADAMS                5
# 1        ALLEN              182
# 2  BARTHOLOMEW               13
# 3        BOONE                8
# 4         CASS                6

# %%
obgyn_by_county_df.describe()
# Out:
#        Providers Count
# count        68.000000
# mean         28.750000
# std          74.668496
# min           1.000000
# 25%           4.000000
# 50%           9.000000
# 75%          22.000000
# max         571.000000

# %%
underlying_cause_df.head()
# Out:
#     CNTY  CHILD_DEATH_YR                                     UNDERLYING_COD  \
# 0  ADAMS            2010  Other specified noninfective disorders of lymp...
# 1  ADAMS            2010  Unspecified pulmonary hemorrhage originating i...
# 2  ADAMS            2010  Congenital malformation of the heart, unspecified
# 3  ADAMS            2010                     Polycystic kidney, unspecified
# 4  ADAMS            2011                     Primary atelectasis of newborn
#
#    CNT_BY_UNDERLYING_COD  CNTY_YR_DEATH_TOTAL  PCT_CNTY_YR_TOTAL  \
# 0                      1                    4               25.0
# 1                      1                    4               25.0
# 2                      1                    4               25.0
# 3                      1                    4               25.0
# 4                      1                    5               20.0
#
#    CHILD_DEATH_CNTY_POP  CNTY_YR_DEATH_TOTAL_PER_10000_CNTY_RES
# 0                 34387                                    1.16
# 1                 34387                                    1.16
# 2                 34387                                    1.16
# 3                 34387                                    1.16
# 4                 34384                                    1.45

# %%
underlying_cause_df.describe()
# Out:
#        CHILD_DEATH_YR  CNT_BY_UNDERLYING_COD  CNTY_YR_DEATH_TOTAL  \
# count     2393.000000            2393.000000          2393.000000
# mean      2014.029252               1.193481            16.910990
# std          2.531239               0.717501            21.224887
# min       2010.000000               1.000000             1.000000
# 25%       2012.000000               1.000000             3.000000
# 50%       2014.000000               1.000000             7.000000
# 75%       2016.000000               1.000000            19.000000
# max       2018.000000              11.000000            72.000000
#
#        PCT_CNTY_YR_TOTAL  CHILD_DEATH_CNTY_POP  \
# count        2393.000000           2393.000000
# mean           24.713725         272709.632679
# std            26.714584         308761.865396
# min             1.388800           8166.000000
# 25%             6.250000          44013.000000
# 50%            16.666600         143535.000000
# 75%            33.333300         363265.000000
# max           100.000000         941229.000000
#
#        CNTY_YR_DEATH_TOTAL_PER_10000_CNTY_RES
# count                             2393.000000
# mean                                 0.661463
# std                                  0.340800
# min                                  0.050000
# 25%                                  0.440000
# 50%                                  0.620000
# 75%                                  0.770000
# max                                  3.150000

# %%
population_data_df.head()
# Out:
#       Unnamed: 0       Census Estimates Base         2010         2011  \
# 0  United States  308,745,538    308,758,105  309,321,666  311,556,874
# 1      Northeast   55,317,240     55,318,443   55,380,134   55,604,223
# 2        Midwest   66,927,001     66,929,725   66,974,416   67,157,800
# 3          South  114,555,744    114,563,030  114,866,680  116,006,522
# 4           West   71,945,553     71,946,907   72,100,436   72,788,329
#
#           2012         2013         2014         2015         2016  \
# 0  313,830,990  315,993,715  318,301,008  320,635,163  322,941,311
# 1   55,775,216   55,901,806   56,006,011   56,034,684   56,042,330
# 2   67,336,743   67,560,379   67,745,167   67,860,583   67,987,540
# 3  117,241,208  118,364,400  119,624,037  120,997,341  122,351,760
# 4   73,477,823   74,167,130   74,925,793   75,742,555   76,559,681
#
#           2017         2018         2019
# 0  324,985,539  326,687,501  328,239,523
# 1   56,059,240   56,046,620   55,982,803
# 2   68,126,781   68,236,628   68,329,004
# 3  123,542,189  124,569,433  125,580,448
# 4   77,257,329   77,834,820   78,347,268

# %%
population_data_df.describe()
# Out:
#        Unnamed: 0     Census Estimates Base       2010       2011     2012  \
# count          62         57             57         57         57       57
# unique         62         57             57         57         57       57
# top     .Nebraska  2,700,551      1,316,462  2,775,332  5,121,108  701,176
# freq            1          1              1          1          1        1
#
#              2013        2014       2015        2016       2017        2018  \
# count          57          57         57          57         57          57
# unique         57          57         57          57         57          57
# top     4,764,080  12,788,313  3,120,960  11,634,370  1,424,393  10,511,131
# freq            1           1          1           1          1           1
#
#              2019
# count          57
# unique         57
# top     1,787,065
# freq            1
